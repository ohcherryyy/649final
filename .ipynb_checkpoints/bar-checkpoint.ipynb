# %%
import pandas as pd
import altair as alt
import numpy as np
import pprint

# %%
df = pd.read_csv("vgsales.csv")

# %%
Nintendo_df = df[df.Publisher.str.contains('Nintendo') == True]

# %%
Nintendo_df
# Out:
#         Rank                                         Name Platform    Year  \
# 0        1.0                                       Tetris   Series  1989.0
# 1        2.0                                      Pokemon   Series  1998.0
# 3        4.0                                  Super Mario   Series  1983.0
# 10      11.0                                   Mario Kart   Series  1992.0
# 18      19.0                          The Legend of Zelda   Series  1987.0
# ...      ...                                          ...      ...     ...
# 4904  4905.0                             Tales of Rebirth       GC  2001.0
# 4936  4937.0           International Superstar Soccer '98      N64  2000.0
# 4959  4960.0  From TV Animation One Piece: Grand Battle 2      Wii  2009.0
# 4983  4984.0                   Tales from the Borderlands      N64  1998.0
# 4997  4998.0         Crash Bandicoot: The Wrath of Cortex       DS  2006.0
#
#                  Genre   Publisher  \
# 0               Puzzle  Nintendo
# 1         Role-Playing  Nintendo
# 3             Platform  Nintendo
# 10              Racing  Nintendo
# 18    Action-Adventure  Nintendo
# ...                ...         ...
# 4904            Racing  Nintendo
# 4936            Racing  Nintendo
# 4959          Platform  Nintendo
# 4983            Sports  Nintendo
# 4997            Puzzle  Nintendo
#
#                                        Developer  Critic_Score  User_Score  \
# 0                              Alexey Pajitnov             NaN         NaN
# 1                                   Game Freak             NaN         NaN
# 3                                     Nintendo             NaN         NaN
# 10                                    Nintendo             NaN         NaN
# 18                                    Nintendo             NaN         NaN
# ...                                          ...           ...         ...
# 4904  Nintendo Software Technology Corporation             8.4         NaN
# 4936                                 Rare Ltd.             NaN         NaN
# 4959                        Nintendo EAD Tokyo             NaN         NaN
# 4983                                   Tikipod             NaN         NaN
# 4997                      Genius Sonority Inc.             NaN         NaN
#
#       NA_Sales  PAL_Sales  JP_Sales  Other_Sales  Global_Sales
# 0          NaN        NaN       NaN          NaN           NaN
# 1          NaN        NaN       NaN          NaN           NaN
# 3          NaN        NaN       NaN          NaN           NaN
# 10         NaN        NaN       NaN          NaN           NaN
# 18         NaN        NaN       NaN          NaN           NaN
# ...        ...        ...       ...          ...           ...
# 4904      0.40       0.10      0.09         0.02          0.60
# 4936      0.37       0.08      0.14         0.01          0.60
# 4959      0.23       0.17      0.14         0.05          0.60
# 4983      0.48       0.11       NaN          NaN          0.59
# 4997      0.25       0.00      0.31         0.02          0.59
#
# [532 rows x 14 columns]

# %%
rank50 =df.sort_values(by='Global_Sales', ascending=False).head(50)
rank50
# Out:
#       Rank                                          Name Platform    Year  \
# 23    24.0                                    Wii Sports      Wii  2006.0
# 66    67.0                             Super Mario Bros.      NES  1985.0
# 74    75.0                                Mario Kart Wii      Wii  2008.0
# 87    88.0                             Wii Sports Resort      Wii  2009.0
# 92    93.0            Pokémon Red / Green / Blue Version       GB  1998.0
# 98    99.0                                        Tetris       GB  1989.0
# 96    97.0                         New Super Mario Bros.       DS  2006.0
# 98             Puzzle                     Nintendo
# 96           Platform                     Nintendo
# 107              Misc                     Nintendo
# 97           Platform                     Nintendo
# 106           Shooter                     Nintendo
# 130        Simulation                     Nintendo
# 133            Racing                     Nintendo
# 134      Role-Playing                     Nintendo
# 137            Sports                     Nintendo
# 127             Party       Microsoft Game Studios
# 142            Sports                     Nintendo
# 184            Action               Rockstar Games
# 146          Platform                     Nintendo
# 147            Action               Rockstar Games
# 172              Misc                     Nintendo
# 168            Action               Rockstar Games
# 180      Role-Playing                     Nintendo
# 179          Platform                     Nintendo
# 185          Platform                     Nintendo
# 203            Action               Rockstar Games
# 198      Role-Playing                     Nintendo
# 210            Action               Rockstar Games
# 202      Role-Playing                     Nintendo
# 176            Racing                     Nintendo
# 232              Misc                     Nintendo
# 211      Role-Playing                     Nintendo
# 200      Role-Playing                     Nintendo
# 214           Shooter                   Activision
# 231            Racing  Sony Computer Entertainment
# 233           Shooter                   Activision
# 234           Shooter                   Activision
# 235      Role-Playing                     Nintendo
# 250  Action-Adventure               Rockstar Games
# 251           Shooter                   Activision
# 252           Shooter                   Activision
# 255           Shooter                   Activision
# 257           Shooter                   Activision
# 259           Shooter                   Activision
# 261            Action               Rockstar Games
# 61             Racing                     Nintendo
# 260          Fighting                     Nintendo
# 239      Role-Playing                     Nintendo
# 275           Shooter                   Activision
# 308        Simulation                     Nintendo
# 238           Shooter       Microsoft Game Studios
#
#                           Developer  Critic_Score  User_Score  NA_Sales  \
# 23                   Nintendo EAD             7.7         NaN     41.36
# 66                   Nintendo EAD            10.0         8.2     29.08
# 74                   Nintendo EAD             8.2         9.1     15.91
# 87                   Nintendo EAD             8.0         8.8     15.61
# 92                     Game Freak             9.4         NaN     11.27
# 98          Bullet Proof Software             NaN         NaN     23.20
# 96                   Nintendo EAD             9.1         8.1     11.28
# 107                  Nintendo EAD             5.9         4.5     13.96
# 97                   Nintendo EAD             8.6         9.2     14.53
# 106                 Nintendo R&D1             NaN         NaN     26.93
# 130                  Nintendo EAD             8.4         NaN      9.05
# 133                  Nintendo EAD             9.1         9.4      9.71
# 134                    Game Freak             9.2         NaN      9.00
# 137                  Nintendo EAD             7.9         NaN      8.92
# 127           Good Science Studio             6.7         NaN     15.09
# 142                  Nintendo EAD             8.0         NaN      9.01
# 184                Rockstar North             9.5         NaN      9.43
# 146                  Nintendo EAD             8.5         NaN     12.78
# 147                Rockstar North             9.4         NaN      6.37
# 172                  Nintendo SDD             8.1         NaN      4.74
# 168                Rockstar North             9.7         NaN      6.06
# 180                    Game Freak             8.6         NaN      6.38
# 179                 Nintendo R&D1             NaN         NaN     10.83
# 185                 Nintendo R&D2             NaN         NaN      9.54
# 203                Rockstar North             9.6         NaN      8.41
# 198                    Game Freak             8.9         9.7      5.68
# 210                Rockstar North             NaN         NaN      9.06
# 259       5.78      0.49         1.54         13.35
# 261       4.51      0.30         1.30         13.10
# 61        4.98      2.11         0.91         13.05
# 260       2.57      2.67         1.03         12.91
# 239       3.98      3.15         0.82         12.73
# 275       4.40      0.48         1.78         12.67
# 308       3.46      5.33         0.86         12.14
# 238       2.81      0.13         1.21         12.13

# %%
region_order = ['NA_Sales', 'JP_Sales', 'PAL_Sales', 'Other_Sales']
re = ['America', 'Japan', 'PAL', 'Other Regions']

bar = alt.Chart(rank50, title="Regional Sales of Top 50 Video Games",width=800).transform_fold(
  ['NA_Sales', 'JP_Sales', 'PAL_Sales', 'Other_Sales'],
  as_=['Regional_Sales', 'Amount']
).mark_bar().encode(
  x=alt.X('Publisher:N', sort='-y'),
  y=alt.Y('Amount:Q', title='Sales (million $)'),
  color=alt.Color('sum(Regional_Sales):N', sort=region_order),
  order=alt.Order('region_order:Q'),
    opacity=alt.condition(alt.datum.Publisher=='Nintendo  ',alt.value(1),alt.value(0.4))
)

chart = alt.layer(bar).configure_title(fontSize=18, anchor="middle").configure_legend(titleFontSize=14,labelFontSize=12).configure_axis(titleFontSize=14,labelFontSize=11) 

barr = chart.encode(
    tooltip=['Name:N','Regional_Sales:N','Amount:Q','Global_Sales:Q','Genre:N']
)

barr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     382
#     383         try:
# --> 384             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     385         except jsonschema.ValidationError:
#     386             dct = None
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     324             result = _todict(self._args[0], validate=sub_validate, context=context)
#     325         elif not self._args:
# --> 326             result = _todict(
#     327                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     328                 validate=sub_validate,
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     382
#     383         try:
# --> 384             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     385         except jsonschema.ValidationError:
#     386             dct = None
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     324             result = _todict(self._args[0], validate=sub_validate, context=context)
#     325         elif not self._args:
# --> 326             result = _todict(
#     327                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     328                 validate=sub_validate,
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     324             result = _todict(self._args[0], validate=sub_validate, context=context)
#     325         elif not self._args:
# --> 326             result = _todict(
#     327                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     328                 validate=sub_validate,
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~/opt/anaconda3/envs/si649/lib/python3.9/site-packages/altair/vegalite/v4/schema/channels.py in to_dict(self, validate, ignore, context)
#      38             elif not (type_in_shorthand or type_defined_explicitly):
#      39                 if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40                     raise ValueError("{} encoding field is specified without a type; "
#      41                                      "the type cannot be inferred because it does not "
#      42                                      "match any column in the data.".format(shorthand))
#
# ValueError: sum(Regional_Sales:N) encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.
# alt.LayerChart(...)

# %%
region_order = ['NA_Sales', 'JP_Sales', 'PAL_Sales', 'Other_Sales']
re = ['America', 'Japan', 'PAL', 'Other Regions']

point = alt.Chart(rank50, title="Regional_Sales of Top 50 Nintendo Video Games").transform_fold(
  ['NA_Sales', 'JP_Sales', 'PAL_Sales', 'Other_Sales'],
  as_=['Regional_Sales', 'Amount']
).mark_point().encode(
  x=alt.X('Name:N', sort='-y'),
  y=alt.Y('Amount:Q', title='Sales (million $)'),
  color=alt.Color('Regional_Sales:N', sort=region_order),
  order=alt.Order('region_order:Q')
)

chart = alt.layer(point).configure_title(fontSize=18, anchor="middle").configure_legend(titleFontSize=14,labelFontSize=12).configure_axis(titleFontSize=14,labelFontSize=11) 

pointt = chart.encode(
    tooltip=['Name:N','Regional_Sales:N','Amount:Q','Global_Sales:Q']
)

pointt
# Out:
# alt.LayerChart(...)
