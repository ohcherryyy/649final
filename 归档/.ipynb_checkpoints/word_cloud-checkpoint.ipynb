# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('vgsales.csv')

# %%
df1 = df.dropna(subset=['Global_Sales'])

# %%
publisher = df1.groupby('Publisher').sum('Global_Sales').sort_values(by=['Global_Sales'], ascending=False)
publisher.head()
# Out:
#                                    Rank      Year  Critic_Score  User_Score  \
# Publisher
# Nintendo                       862888.0  885645.0        2388.7       311.6
# Activision                     728437.0  507784.0        1003.5        94.8
# Electronic Arts                952233.0  676501.0        1399.5        78.6
# Sony Computer Entertainment    603494.0  449155.0        1048.6       201.2
# EA Sports                      731315.0  503665.0         867.3         9.1
#
#                                NA_Sales  PAL_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                         825.10     445.87    446.41       100.27
# Activision                       310.48     177.07      6.94        62.06
# Electronic Arts                  262.39     210.78      7.16        65.51
# Sony Computer Entertainment      203.83     148.06     49.45        67.20
# EA Sports                        222.66     138.87      2.86        51.42
#
#                                Global_Sales
# Publisher
# Nintendo                            1817.74
# Activision                           556.44
# Electronic Arts                      545.82
# Sony Computer Entertainment          468.62
# EA Sports                            415.78

# %%
d = dict(zip(publisher.index, publisher.Global_Sales))
wordcloud = WordCloud(collocations=False,width=3840,height=2160,background_color="white").generate_from_frequencies(d).to_file('test.jpg')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
# Out:
# (-0.5, 3839.5, 2159.5, -0.5)
